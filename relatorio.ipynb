# %% [markdown]
# ## Listando sistemas de timetabling e suas características

# %%
import pandas as pd 

dt_timetabling = pd.read_csv('./timetabling-systems.csv')

dt_timetabling
# Out:
#             Nome                                Link  \
# 0         Urânia  https://www.programaurania.com.br/
# 1            ASC        http://www.asctimetables.com
# 2           Sdui            https://sdui.de/?lang=en
# 3        UniTime             https://www.unitime.org
# 4  Horário Fácil   http://www.horariofacil.com/pt-BR
# 5     TimeTabler         https://www.timetabler.com/
# 6        Docendo           https://zen.docendo.no/pt
# 7            FET       https://lalescu.ro/liviu/fet/
# 8            GHC      https://www.penalara.com/en/BR
#
#                         Empresa      Cidade         País Software Comercial  \
# 0                 Geha Sistemas    Curitiba       Brasil                Sim
# 1  Applied Software Consultants       Adyar        Índia                Sim
# 2                     Sdui GmbH      Berlim     Alemanha                Sim
# 3                           NaN         NaN          NaN                Não
# ...

# %% [markdown]
# ## TimeTabler
#
# Aplicação Desktop, licenciada mas parece ser obsoleta.
#
# ### Home
# ![image](./timetabler/home.png)
#
# ### Resolvedor
# ![image](./timetabler/solver.png)
#
# ### Agendamento
# ![image](./timetabler/atividades.png)
#
# ### Dados básicos
# ![image](./timetabler/basic-data.png)
#
# ### Configurações
# ![image](./timetabler/configurações.png)
#
# ### Check
# ![image](./timetabler/check.png)
#
# ### Atividades
# ![image](./timetabler/atividades.png)

# %% [markdown]
# ## Docendo
# Aplicação Web, vídeos tutorial podem ser obtidos no [link](https://zen.docendo.no/pt/academy)
#
# ### Preços
# ![image](./docendo/precos.png)
#
# ### Criando primeiro horário
# ![image](./docendo/criando_primeiro_horario.png)
#
# ### Professores
# ![image](./docendo/professores.png)
#
# ### Turmas
# ![image](./docendo/turmas.png)
#
# ### Configuração Horários
# ![image](./docendo/config-horarios.png)
#
# ### Disciplinas
# ![image](./docendo/disciplinas.png)
#
# ### Distribuição das Disciplinas
# ![image](./docendo/disciplinas2.png)

# %% [markdown]
# ## FET
#
# Aplicação Desktop, aparentemente desenvolvido em C++. Manual de ajuda no [link](https://lalescu.ro/liviu/fet/doc/en/Learn-FET-with-a-sample-file.pdf)
#
# ### Home - File
# ![image](./fet/home.png)
#
# ### Home - Data
# ![image](./fet/data.png)
#
# ### Home - Time
# ![image](./fet/time.png)
#
# ### Home - Space
# ![image](./fet/space.png)
#
# ### Home - Timetabling
# ![image](./fet/timetabling.png)
#
# ### Planejamento de atividades
# ![image](./fet/atividades.png)
#
# ### Visão do horário - alunos
# ![image](./fet/visao-aluno.png)

# %% [markdown]
# ## GFC - Penalera Software
#
# Aplicação Desktop, aparentemente desenvolvida em Java. Playlist de 22 vídeos tutorias no [link](https://www.penalara.com/pt/ES/videotutoriales/).
#
# ### Precificação
# ![image](./ghc/precos.png)
#
# ### Tela de cadastro de professores
# ![image](./ghc/teachers.png){width=25px}
#
# ### Tela de cadastro de professores - configuração inline
# ![image](./ghc/teachers-config-inline.png)
#
# ### Tela de configurações avançadas
# ![image](./ghc/teachers-config-advanced.png)
#
# ### Configurações de pesos de opções
# ![image](./ghc/config.png)
#
# ### Imagem da grade - visão dos estudantes
# ![image](./ghc/grade-students.png)
#
# ### Imagem da grade - visão dos professores
# ![image](./ghc/grade-teacher.png)
